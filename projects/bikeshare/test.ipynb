# %%
import pandas as pd
import folium

# %%
import json

with open("data/omaha/coords.json", "r") as f:
    coords = json.load(f)

# %%
type(coords)
# Out:
# dict

# %%
mymap = folium.Map(location=[41.256538, -95.934502], zoom_start=13)

# Add markers for each coordinate
for kiosk, coord in coords.items():
    lat, lon = map(float, coord.split(','))
    folium.Marker([lat, lon], popup=kiosk).add_to(mymap)


mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa0d7fe7182536bb171de752c1e4f270 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa0d7fe7182536bb171de752c1e4f270&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa0d7fe7182536bb171de752c1e4f270 = L.map(
#                 &quot;map_aa0d7fe7182536bb171de752c1e4f270&quot;,
#                 {
#                     center: [41.256538, -95.934502],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9310b9d9bbdb48e554ab6730f126c5e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f9310b9d9bbdb48e554ab6730f126c5e.addTo(map_aa0d7fe7182536bb171de752c1e4f270);
#
#
#             var marker_94263f8aa7b4ef97aabb0c5abc335b0b = L.marker(
#                 [39.97233, -75.145],
#                 {}
#             ).addTo(map_aa0d7fe7182536bb171de752c1e4f270);
#
#
#         var popup_ffa845f480244e2a3bf82a26a3756e9d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d85e0d0ee6a15a58d7d93193599aba4d = $(`&lt;div id=&quot;html_d85e0d0ee6a15a58d7d93193599aba4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Heartland Helpdesk&lt;/div&gt;`)[0];
#                 popup_ffa845f480244e2a3bf82a26a3756e9d.setContent(html_d85e0d0ee6a15a58d7d93193599aba4d);
#
#
#
#         marker_94263f8aa7b4ef97aabb0c5abc335b0b.bindPopup(popup_ffa845f480244e2a3bf82a26a3756e9d)
#         ;
#
#
#
#
#             var marker_eafdb919cf244ef85a4630c4778eef4a = L.marker(
#                 [41.03038, -96.31184],
#                 {}
#             ).addTo(map_aa0d7fe7182536bb171de752c1e4f270);
#
#
#         var popup_d94c5dd485e9a1732ff33ffc95d5637f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_494cf2e563d714e2eff0db27491019cf = $(`&lt;div id=&quot;html_494cf2e563d714e2eff0db27491019cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mahoney State Park&lt;/div&gt;`)[0];
#                 popup_d94c5dd485e9a1732ff33ffc95d5637f.setContent(html_494cf2e563d714e2eff0db27491019cf);
#
#
#
#         marker_eafdb919cf244ef85a4630c4778eef4a.bindPopup(popup_d94c5dd485e9a1732ff33ffc95d5637f)
#         ;
#
#
#
#
#             var marker_5c674b548deecbb33e1b758ebc111ad8 = L.marker(
#                 [41.13997, -96.06433],
#                 {}
#             ).addTo(map_aa0d7fe7182536bb171de752c1e4f270);
#
#
#         var popup_81c2adfe04e5b084080e9646ec10bb79 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1f23d1898894d58ae94eb12ad1c0cba7 = $(`&lt;div id=&quot;html_1f23d1898894d58ae94eb12ad1c0cba7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Walnut Creek Recreation Area (Papillion)&lt;/div&gt;`)[0];
#                 popup_81c2adfe04e5b084080e9646ec10bb79.setContent(html_1f23d1898894d58ae94eb12ad1c0cba7);
#
#
#
#         marker_5c674b548deecbb33e1b758ebc111ad8.bindPopup(popup_81c2adfe04e5b084080e9646ec10bb79)
#         ;
#
#
#
#
#             var marker_8d4b6dce5b637afbbe2111505ff67b20 = L.marker(
#                 [41.14896, -95.96814],
#                 {}
#             ).addTo(map_aa0d7fe7182536bb171de752c1e4f270);
#
#
#         var popup_ec427b3861ff34a93bacaf5efa31beca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_449c1d3de97e09ca1f4b5241d8836418 = $(`&lt;div id=&quot;html_449c1d3de97e09ca1f4b5241d8836418&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;36th &amp; Raynor Parkway (Bellevue)&lt;/div&gt;`)[0];
#                 popup_ec427b3861ff34a93bacaf5efa31beca.setContent(html_449c1d3de97e09ca1f4b5241d8836418);
#
#
#
#         marker_8d4b6dce5b637afbbe2111505ff67b20.bindPopup(popup_ec427b3861ff34a93bacaf5efa31beca)
#         ;
#
#
#
#
#             var marker_d5c9ab518e03af0bd3b319a88da36290 = L.marker(
#                 [41.15487, -96.1124],
#                 {}
#             ).addTo(map_aa0d7fe7182536bb171de752c1e4f270);
#
#
#         var popup_6bc76b928926fb7bac3d4c1ae298868d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0b470dd5775da7e6fb4f0451e22b42e6 = $(`&lt;div id=&quot;html_0b470dd5775da7e6fb4f0451e22b42e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Prairie Queen Recreation Area (Papillion)&lt;/div&gt;`)[0];
#                 popup_6bc76b928926fb7bac3d4c1ae298868d.setContent(html_0b470dd5775da7e6fb4f0451e22b42e6);
#
#
#
#         marker_d5c9ab518e03af0bd3b319a88da36290.bindPopup(popup_6bc76b928926fb7bac3d4c1ae298868d)
#         ;
#
#
#
#
#             var marker_c1511d493afd84239ba5d4bc9be5f50d = L.marker(
#                 [41.15593, -96.05576],

# %%
df = pd.read_csv("data/omaha/OMA_Bike_Trips_wt_avg_time_bin.csv")

# %%
df.sort_values(by=['Total_Trips'], ascending=False, inplace=True)

# %%
import plotly.express as px

df = pd.read_csv("data/omaha/OMA_Bike_Trips_wt_avg_time_bin.csv")

# Sort the DataFrame by 'Total_Trips' column
df_sorted = df.sort_values(by='Total_Trips', ascending=False)

# Select the top 15 rows
top_kiosks = df_sorted.head(20)

# Plot using Plotly
fig = px.bar(top_kiosks, x='Checkout_Kiosk_Coordinates', y='Total_Trips', title='Most used Kiosk Locations')

# rename the x-axis label
fig.update_xaxes(title_text='Checkout Kiosk Address')

# rename the y-axis label
fig.update_yaxes(title_text='Total Trips')

# change the angle of the x-axis labels
fig.update_layout(xaxis_tickangle=-45)


fig.show()
